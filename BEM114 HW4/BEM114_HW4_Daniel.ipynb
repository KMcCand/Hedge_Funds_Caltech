# %% [markdown]
# # BEM114 Homework 4 - Risk-Weighted Portfolios
# **Names:** Andrew Zabelo, Daniel Wen, Kyle McCandless
# **Student IDs:** 2176083, 2159859, 2157818
#
# ## Setup
#
# ### Imports and Helper Functions

# %%
import pandas as pd
import numpy as np

from datetime import datetime
from dateutil.relativedelta import relativedelta

import statsmodels.api as sm
import matplotlib.pyplot as plt

# %%
# Estimates the CAPM and FF3 models on df_old using the returns found in ret_col_name
def estimate_models(df, return_col_name, factor):
    # Estimate CAPM
    print(f'\n\n{factor} CAPM')
    capm_model = sm.OLS(df[return_col_name], sm.add_constant(df[['Mkt-RF']])).fit()
    capm_beta = capm_model.params['Mkt-RF']
    print(capm_model.summary())
    
    # Estimate FF3
    print(f'\n{factor} FF3')
    print(sm.OLS(df[return_col_name], sm.add_constant(df[['Mkt-RF', 'SMB', 'HML']])).fit().summary())
    
    # Estimate FF5
    print(f'\n{factor} FF5+Mom')
    print(sm.OLS(df[return_col_name], sm.add_constant(df[['Mkt-RF', 'SMB', 'HML', 'RMW', 'CMA', 'Mom']])).fit().summary())

# %% [markdown]
# ## Problem 1
#
# ### Part A - Process Dataframes

# %%
'''
Load FF5 daily and monthly data
'''

ff5_daily = pd.read_csv('ff5_daily.csv')
ff5_daily = ff5_daily.astype({'date': 'string'})
ff5_daily['date'] = ff5_daily['date'].apply(lambda x: x[:4] + '-' + x[4:6] + '-' + x[6:])
mom_daily = pd.read_csv('mom_daily.CSV')
mom_daily = mom_daily.astype({'date': 'string'})
mom_daily['date'] = mom_daily['date'].apply(lambda x: x[:4] + '-' + x[4:6] + '-' + x[6:])
ff6_daily = pd.merge(ff5_daily, mom_daily, how='inner', on=['date'])

ff5_monthly = pd.read_csv('ff5_monthly.csv')
ff5_monthly = ff5_monthly.astype({'date': 'string'})
ff5_monthly['date'] = ff5_monthly['date'].apply(lambda x: x[:4] + '-' + x[4:])
mom_monthly = pd.read_csv('mom_monthly.CSV')
mom_monthly = mom_monthly.astype({'date': 'string'})
mom_monthly['date'] = mom_monthly['date'].apply(lambda x: x[:4] + '-' + x[4:])
ff6_monthly = pd.merge(ff5_monthly, mom_monthly, how='inner', on=['date'])

# %% [markdown]
# ### Part B - Calculate Rolling Variance of Factor Returns

# %%
def make_rolling_var(df, factor):
    rolling_var = ff6_daily[factor].rolling(window=22, min_periods=22).var()
    rolling_var = pd.Series(rolling_var.values).rename(f'var_{factor}')
    ff6_daily[f'var_{factor}'] = rolling_var

# %%
# make the rolling variances
factors = ['Mkt-RF', 'SMB', 'HML', 'RMW', 'CMA', 'Mom']
for factor in factors:
    make_rolling_var(ff6_daily, factor)

ff6_daily
# Out:
#              date  Mkt-RF   SMB   HML   RMW   CMA     RF   Mom  var_Mkt-RF  \
# 0      1963-07-01   -0.67  0.02 -0.35  0.03  0.13  0.012 -0.21         NaN
# 1      1963-07-02    0.79 -0.28  0.28 -0.08 -0.21  0.012  0.42         NaN
# 2      1963-07-03    0.63 -0.18 -0.10  0.13 -0.25  0.012  0.41         NaN
# 3      1963-07-05    0.40  0.09 -0.28  0.07 -0.30  0.012  0.07         NaN
# 4      1963-07-08   -0.63  0.07 -0.20 -0.27  0.06  0.012 -0.45         NaN
# ...           ...     ...   ...   ...   ...   ...    ...   ...         ...
# 15285  2024-03-22   -0.23 -0.98 -0.53  0.29 -0.37  0.021  0.43    0.505910
# 15286  2024-03-25   -0.26 -0.10  0.88 -0.22 -0.17  0.021 -0.34    0.349962
# 15287  2024-03-26   -0.26  0.10 -0.13 -0.50  0.23  0.021  0.09    0.355926
# 15288  2024-03-27    0.88  1.29  0.91 -0.14  0.58  0.021 -1.34    0.376593
# 15289  2024-03-28    0.10  0.45  0.48 -0.07  0.09  0.021 -0.44    0.375942
#
#         var_SMB   var_HML   var_RMW   var_CMA   var_Mom
# 0           NaN       NaN       NaN       NaN       NaN
# 1           NaN       NaN       NaN       NaN       NaN
# 2           NaN       NaN       NaN       NaN       NaN
# 3           NaN       NaN       NaN       NaN       NaN
# 4           NaN       NaN       NaN       NaN       NaN
# ...         ...       ...       ...       ...       ...
# 15285  0.708938  0.458988  0.309487  0.250368  0.683857
# 15286  0.607054  0.395853  0.307150  0.185330  0.517176
# 15287  0.601206  0.397961  0.319346  0.186243  0.516868
# 15288  0.637681  0.421055  0.293502  0.199281  0.558861
# 15289  0.568274  0.404085  0.226731  0.181229  0.552656
#
# [15290 rows x 14 columns]

# %% [markdown]
# ### Part C - Collapse Data to End of Month And Regress Current Variance on Lag Variance

# %%
ff6_daily['date'] = pd.to_datetime(ff6_daily['date'])
ff6_daily.set_index('date', inplace=True)
df_ff6 = ff6_daily.resample('M').last()

factors = ['Mkt-RF', 'SMB', 'HML', 'RMW', 'CMA', 'Mom']
for factor in factors:
    df_ff6[f'lag_var_{factor}'] = df_ff6[f'var_{factor}'].shift(1)

df_ff6 = df_ff6.iloc[1:].reset_index()
df_ff6['date']
# Out:
# 0     1963-08-31
# 1     1963-09-30
# 2     1963-10-31
# 3     1963-11-30
# 4     1963-12-31
#          ...
# 723   2023-11-30
# 724   2023-12-31
# 725   2024-01-31
# 726   2024-02-29
# 727   2024-03-31
# Name: date, Length: 728, dtype: datetime64[ns]

# %%
for factor in factors:
    temp = df_ff6.dropna(subset=[f'var_{factor}', f'lag_var_{factor}'])
    print(f"\n\n{factor}")
    print(sm.OLS(temp[f'var_{factor}'], sm.add_constant(temp[[f'lag_var_{factor}']])).fit().summary())
# Out:
# Mkt-RF
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             var_Mkt-RF   R-squared:                       0.207
# Model:                            OLS   Adj. R-squared:                  0.206
# Method:                 Least Squares   F-statistic:                     189.9
# Date:                Tue, 07 May 2024   Prob (F-statistic):           1.51e-38
# Time:                        23:45:00   Log-Likelihood:                -1519.8
# No. Observations:                 728   AIC:                             3044.
# Df Residuals:                     726   BIC:                             3053.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.5672      0.080      7.073      0.000       0.410       0.725
# lag_var_Mkt-RF     0.4553      0.033     13.781      0.000       0.390       0.520
# ==============================================================================
# Omnibus:                     1236.538   Durbin-Watson:                   2.071
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           725257.224
# Skew:                          10.642   Prob(JB):                         0.00
# Kurtosis:                     156.155   Cond. No.                         2.78
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# SMB
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                var_SMB   R-squared:                       0.136
# Model:                            OLS   Adj. R-squared:                  0.134
# Method:                 Least Squares   F-statistic:                     114.0
# Date:                Tue, 07 May 2024   Prob (F-statistic):           8.20e-25
# Time:                        23:45:00   Log-Likelihood:                -463.72
# No. Observations:                 728   AIC:                             931.4
# Df Residuals:                     726   BIC:                             940.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           0.1857      0.020      9.397      0.000       0.147       0.224
# lag_var_SMB     0.3684      0.035     10.676      0.000       0.301       0.436
# ==============================================================================
# Omnibus:                     1324.074   Durbin-Watson:                   2.111
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1503081.930
# Skew:                          11.992   Prob(JB):                         0.00
# Kurtosis:                     224.307   Cond. No.                         2.25
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# HML
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                var_HML   R-squared:                       0.562
# Model:                            OLS   Adj. R-squared:                  0.561
# Method:                 Least Squares   F-statistic:                     930.5
# Date:                Tue, 07 May 2024   Prob (F-statistic):          3.57e-132
# Time:                        23:45:00   Log-Likelihood:                -431.95
# No. Observations:                 728   AIC:                             867.9
# Df Residuals:                     726   BIC:                             877.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           0.0841      0.018      4.621      0.000       0.048       0.120
# lag_var_HML     0.7494      0.025     30.504      0.000       0.701       0.798
# ==============================================================================
# Omnibus:                      737.266   Durbin-Watson:                   2.470
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            65383.289
# Skew:                           4.399   Prob(JB):                         0.00
# Kurtosis:                      48.586   Cond. No.                         1.78
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# RMW
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                var_RMW   R-squared:                       0.522
# Model:                            OLS   Adj. R-squared:                  0.522
# Method:                 Least Squares   F-statistic:                     793.7
# Date:                Tue, 07 May 2024   Prob (F-statistic):          1.43e-118
# Time:                        23:45:00   Log-Likelihood:                 111.28
# No. Observations:                 728   AIC:                            -218.6
# Df Residuals:                     726   BIC:                            -209.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           0.0438      0.009      5.035      0.000       0.027       0.061
# lag_var_RMW     0.7226      0.026     28.173      0.000       0.672       0.773
# ==============================================================================
# Omnibus:                      733.346   Durbin-Watson:                   2.192
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           122814.118
# Skew:                           4.101   Prob(JB):                         0.00
# Kurtosis:                      66.099   Cond. No.                         3.42
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# CMA
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                var_CMA   R-squared:                       0.473
# Model:                            OLS   Adj. R-squared:                  0.472
# Method:                 Least Squares   F-statistic:                     651.3
# Date:                Tue, 07 May 2024   Prob (F-statistic):          4.91e-103
# Time:                        23:45:00   Log-Likelihood:                 311.80
# No. Observations:                 728   AIC:                            -619.6
# Df Residuals:                     726   BIC:                            -610.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           0.0441      0.007      6.324      0.000       0.030       0.058
# lag_var_CMA     0.6876      0.027     25.520      0.000       0.635       0.740
# ==============================================================================
# Omnibus:                      518.536   Durbin-Watson:                   2.343
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            27642.076
# Skew:                           2.579   Prob(JB):                         0.00
# Kurtosis:                      32.743   Cond. No.                         4.70
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Mom
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                var_Mom   R-squared:                       0.396
# Model:                            OLS   Adj. R-squared:                  0.395
# Method:                 Least Squares   F-statistic:                     476.5
# Date:                Tue, 07 May 2024   Prob (F-statistic):           1.33e-81
# Time:                        23:45:00   Log-Likelihood:                -1033.1
# No. Observations:                 728   AIC:                             2070.
# Df Residuals:                     726   BIC:                             2079.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           0.2165      0.041      5.315      0.000       0.137       0.297
# lag_var_Mom     0.6294      0.029     21.829      0.000       0.573       0.686
# ==============================================================================
# Omnibus:                      807.815   Durbin-Watson:                   2.335
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           103546.383
# Skew:                           5.017   Prob(JB):                         0.00
# Kurtosis:                      60.558   Cond. No.                         1.76
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Part D - Regress Future Factor Returns on Variance

# %%
df_ff6 = df_ff6.astype({'date': 'string'})
df_ff6['date'] = df_ff6['date'].apply(lambda x: x[:4] + '-' + x[5:7])
tmp = df_ff6.iloc[:, 8:]
tmp.insert(0, 'date', df_ff6['date'])

df_ff6 = pd.merge(ff6_monthly, tmp, how='inner', on=['date'])
df_ff6
# Out:
#         date  Mkt-RF   SMB   HML   RMW   CMA    RF   Mom  var_Mkt-RF  \
# 0    1963-08    5.07 -0.80  1.80  0.36 -0.35  0.25  1.01    0.086949
# 1    1963-09   -1.57 -0.52  0.13 -0.71  0.29  0.27  0.19    0.154223
# 2    1963-10    2.53 -1.39 -0.10  2.80 -2.01  0.29  3.12    0.171368
# 3    1963-11   -0.85 -0.88  1.75 -0.51  2.24  0.27 -0.74    1.493974
# 4    1963-12    1.83 -2.10 -0.02  0.03 -0.07  0.29  1.75    0.171291
# ..       ...     ...   ...   ...   ...   ...   ...   ...         ...
# 723  2023-11    8.84 -0.12  1.64 -3.91 -1.00  0.44  2.75    0.547768
# 724  2023-12    4.87  7.32  4.93 -3.07  1.32  0.43 -5.51    0.406426
# 725  2024-01    0.71 -5.74 -2.38  0.69 -0.96  0.47  5.19    0.537473
# 726  2024-02    5.06 -0.78 -3.49 -1.99 -2.14  0.42  4.96    0.767954
# 727  2024-03    2.83 -1.16  4.19  1.48  1.18  0.43 -0.42    0.375942
#
#       var_SMB   var_HML   var_RMW   var_CMA   var_Mom  lag_var_Mkt-RF  \
# 0    0.033653  0.039540  0.013295  0.023129  0.047702        0.223726
# 1    0.052577  0.035055  0.028740  0.028083  0.072686        0.086949
# 2    0.077462  0.116457  0.061698  0.085728  0.094405        0.154223
# 3    0.207698  0.079971  0.092893  0.081876  0.639916        0.171368
# 4    0.086630  0.042985  0.063767  0.085114  0.086355        1.493974
# ..        ...       ...       ...       ...       ...             ...
# 723  1.151056  0.410597  0.353418  0.090708  1.064724        0.863721
# 724  0.973010  0.476797  0.187247  0.102177  0.804803        0.547768
# 725  0.613752  0.340327  0.271399  0.087964  0.581611        0.406426
# 726  1.372533  0.458630  0.401818  0.318679  0.893207        0.537473
# 727  0.568274  0.404085  0.226731  0.181229  0.552656        0.767954
#
#      lag_var_SMB  lag_var_HML  lag_var_RMW  lag_var_CMA  lag_var_Mom
# 0       0.020938     0.037883     0.022160     0.031652     0.077050
# 1       0.033653     0.039540     0.013295     0.023129     0.047702
# 2       0.052577     0.035055     0.028740     0.028083     0.072686
# 3       0.077462     0.116457     0.061698     0.085728     0.094405
# 4       0.207698     0.079971     0.092893     0.081876     0.639916
# ..           ...          ...          ...          ...          ...
# 723     0.412867     0.363854     0.428135     0.145862     0.561597
# 724     1.151056     0.410597     0.353418     0.090708     1.064724
# 725     0.973010     0.476797     0.187247     0.102177     0.804803
# 726     0.613752     0.340327     0.271399     0.087964     0.581611
# 727     1.372533     0.458630     0.401818     0.318679     0.893207
#
# [728 rows x 20 columns]

# %%
for factor in factors:
    print(f"\n\n{factor}")
    print(sm.OLS(df_ff6[factor], sm.add_constant(df_ff6[[f'lag_var_{factor}']])).fit().summary())
# Out:
# Mkt-RF
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Mkt-RF   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                  0.007564
# Date:                Tue, 07 May 2024   Prob (F-statistic):              0.931
# Time:                        23:45:00   Log-Likelihood:                -2126.6
# No. Observations:                 728   AIC:                             4257.
# Df Residuals:                     726   BIC:                             4266.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.5858      0.185      3.174      0.002       0.223       0.948
# lag_var_Mkt-RF    -0.0066      0.076     -0.087      0.931      -0.156       0.143
# ==============================================================================
# Omnibus:                       58.161   Durbin-Watson:                   1.912
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              118.267
# Skew:                          -0.493   Prob(JB):                     2.08e-26
# Kurtosis:                       4.711   Cond. No.                         2.78
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# SMB
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    SMB   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.3840
# Date:                Tue, 07 May 2024   Prob (F-statistic):              0.536
# Time:                        23:45:00   Log-Likelihood:                -1841.1
# No. Observations:                 728   AIC:                             3686.
# Df Residuals:                     726   BIC:                             3695.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           0.1626      0.131      1.241      0.215      -0.095       0.420
# lag_var_SMB     0.1418      0.229      0.620      0.536      -0.307       0.591
# ==============================================================================
# Omnibus:                       67.382   Durbin-Watson:                   1.860
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              275.941
# Skew:                           0.317   Prob(JB):                     1.20e-60
# Kurtosis:                       5.949   Cond. No.                         2.25
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# HML
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    HML   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.3245
# Date:                Tue, 07 May 2024   Prob (F-statistic):              0.569
# Time:                        23:45:00   Log-Likelihood:                -1831.8
# No. Observations:                 728   AIC:                             3668.
# Df Residuals:                     726   BIC:                             3677.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           0.3219      0.125      2.585      0.010       0.077       0.566
# lag_var_HML    -0.0957      0.168     -0.570      0.569      -0.426       0.234
# ==============================================================================
# Omnibus:                       44.049   Durbin-Watson:                   1.661
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              158.124
# Skew:                           0.105   Prob(JB):                     4.61e-35
# Kurtosis:                       5.274   Cond. No.                         1.78
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# RMW
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    RMW   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                  0.016
# Method:                 Least Squares   F-statistic:                     13.19
# Date:                Tue, 07 May 2024   Prob (F-statistic):           0.000301
# Time:                        23:45:00   Log-Likelihood:                -1608.0
# No. Observations:                 728   AIC:                             3220.
# Df Residuals:                     726   BIC:                             3229.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           0.1268      0.092      1.376      0.169      -0.054       0.308
# lag_var_RMW     0.9881      0.272      3.632      0.000       0.454       1.522
# ==============================================================================
# Omnibus:                      209.166   Durbin-Watson:                   1.734
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4104.097
# Skew:                          -0.771   Prob(JB):                         0.00
# Kurtosis:                      14.529   Cond. No.                         3.42
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# CMA
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    CMA   R-squared:                       0.022
# Model:                            OLS   Adj. R-squared:                  0.021
# Method:                 Least Squares   F-statistic:                     16.48
# Date:                Tue, 07 May 2024   Prob (F-statistic):           5.45e-05
# Time:                        23:45:00   Log-Likelihood:                -1556.1
# No. Observations:                 728   AIC:                             3116.
# Df Residuals:                     726   BIC:                             3125.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           0.0712      0.091      0.785      0.432      -0.107       0.249
# lag_var_CMA     1.4231      0.351      4.060      0.000       0.735       2.111
# ==============================================================================
# Omnibus:                       23.162   Durbin-Watson:                   1.774
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               51.834
# Skew:                          -0.091   Prob(JB):                     5.55e-12
# Kurtosis:                       4.295   Cond. No.                         4.70
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Mom
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    Mom   R-squared:                       0.033
# Model:                            OLS   Adj. R-squared:                  0.031
# Method:                 Least Squares   F-statistic:                     24.58
# Date:                Tue, 07 May 2024   Prob (F-statistic):           8.88e-07
# Time:                        23:45:00   Log-Likelihood:                -2067.5
# No. Observations:                 728   AIC:                             4139.
# Df Residuals:                     726   BIC:                             4148.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           0.9555      0.169      5.664      0.000       0.624       1.287
# lag_var_Mom    -0.5920      0.119     -4.958      0.000      -0.826      -0.358
# ==============================================================================
# Omnibus:                      162.415   Durbin-Watson:                   2.022
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1347.295
# Skew:                          -0.751   Prob(JB):                    2.75e-293
# Kurtosis:                       9.493   Cond. No.                         1.76
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Part E - Calculate Monthly Volatility Managed Portfolio Excess Returns

# %%
indiv_port = df_ff6.iloc[:, list(range(8)) + list(range(14, len(df_ff6.columns)))].copy()

for factor in factors:
    c = indiv_port[f'lag_var_{factor}'].mean()
    indiv_port[f'lag_weights_{factor}'] = c / indiv_port[f'lag_var_{factor}']

for factor in factors:
    indiv_port[f'returns_{factor}'] = indiv_port[f'{factor}'] * indiv_port[f'lag_weights_{factor}']

indiv_port
# Out:
#         date  Mkt-RF   SMB   HML   RMW   CMA    RF   Mom  lag_var_Mkt-RF  \
# 0    1963-08    5.07 -0.80  1.80  0.36 -0.35  0.25  1.01        0.223726
# 1    1963-09   -1.57 -0.52  0.13 -0.71  0.29  0.27  0.19        0.086949
# 2    1963-10    2.53 -1.39 -0.10  2.80 -2.01  0.29  3.12        0.154223
# 3    1963-11   -0.85 -0.88  1.75 -0.51  2.24  0.27 -0.74        0.171368
# 4    1963-12    1.83 -2.10 -0.02  0.03 -0.07  0.29  1.75        1.493974
# ..       ...     ...   ...   ...   ...   ...   ...   ...             ...
# 723  2023-11    8.84 -0.12  1.64 -3.91 -1.00  0.44  2.75        0.863721
# 724  2023-12    4.87  7.32  4.93 -3.07  1.32  0.43 -5.51        0.547768
# 725  2024-01    0.71 -5.74 -2.38  0.69 -0.96  0.47  5.19        0.406426
# 726  2024-02    5.06 -0.78 -3.49 -1.99 -2.14  0.42  4.96        0.537473
# 727  2024-03    2.83 -1.16  4.19  1.48  1.18  0.43 -0.42        0.767954
#
#      lag_var_SMB  ...  lag_weights_HML  lag_weights_RMW  lag_weights_CMA  \
# 0       0.020938  ...         8.807194         7.074614         4.434829
# 1       0.033653  ...         8.438082        11.792022         6.069087
# 2       0.052577  ...         9.517852         5.454720         4.998408
# 3       0.077462  ...         2.864951         2.540924         1.637404
# 4       0.207698  ...         4.172073         1.687648         1.714455
# ..           ...  ...              ...              ...              ...
# 723     0.412867  ...         0.916973         0.366170         0.962359
# 724     1.151056  ...         0.812583         0.443582         1.547522
# 725     0.973010  ...         0.699762         0.837238         1.373817
# 726     0.613752  ...         0.980364         0.577637         1.595795
# 727     1.372533  ...         0.727479         0.390152         0.440481
#
#      lag_weights_Mom  returns_Mkt-RF  returns_SMB  returns_HML  returns_RMW  \
# 0           7.560788       23.590728   -11.184954    15.852949     2.546861
# 1          12.212486      -18.796775    -4.523336     1.096951    -8.372336
# 2           8.014808       17.077374    -7.739252    -0.951785    15.273217
# 3           6.170911       -5.163423    -3.325620     5.013664    -1.295871
# 4           0.910373        1.275137    -2.959810    -0.083441     0.050629
# ..               ...             ...          ...          ...          ...
# 723         1.037332       10.654367    -0.085084     1.503836    -1.431723
# 724         0.547148        9.255100     1.861621     4.006037    -1.361798
# 725         0.723857        1.818553    -1.726918    -1.665433     0.577694
# 726         1.001635        9.800379    -0.372031    -3.421470    -1.149497
# 727         0.652214        3.836190    -0.247407     3.048137     0.577424
#
#      returns_CMA  returns_Mom
# 0      -1.552190     7.636396
# 1       1.760035     2.320372
# 2     -10.046799    25.006200
# 3       3.667785    -4.566474
# 4      -0.120012     1.593152
# ..           ...          ...
# 723    -0.962359     2.852662
# 724     2.042729    -3.014788
# 725    -1.318864     3.756817
# 726    -3.415002     4.968108
# 727     0.519767    -0.273930
#
# [728 rows x 26 columns]

# %%
for factor in factors:
    estimate_models(indiv_port, f'returns_{factor}', factor)
# Out:
# Mkt-RF CAPM
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         returns_Mkt-RF   R-squared:                       0.450
# Model:                            OLS   Adj. R-squared:                  0.449
# Method:                 Least Squares   F-statistic:                     593.1
# Date:                Tue, 07 May 2024   Prob (F-statistic):           3.22e-96
# Time:                        23:45:00   Log-Likelihood:                -2570.3
# No. Observations:                 728   AIC:                             5145.
# Df Residuals:                     726   BIC:                             5154.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.4944      0.309      1.599      0.110      -0.113       1.101
# Mkt-RF         1.6626      0.068     24.353      0.000       1.529       1.797
# ==============================================================================
# Omnibus:                      358.568   Durbin-Watson:                   1.917
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8478.034
# Skew:                           1.677   Prob(JB):                         0.00
# Kurtosis:                      19.378   Cond. No.                         4.57
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Mkt-RF FF3
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         returns_Mkt-RF   R-squared:                       0.450
# Model:                            OLS   Adj. R-squared:                  0.448
# Method:                 Least Squares   F-statistic:                     197.4
# Date:                Tue, 07 May 2024   Prob (F-statistic):           1.52e-93
# Time:                        23:45:00   Log-Likelihood:                -2570.1
# No. Observations:                 728   AIC:                             5148.
# Df Residuals:                     724   BIC:                             5167.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.4684      0.312      1.501      0.134      -0.144       1.081
# Mkt-RF         1.6734      0.073     22.970      0.000       1.530       1.816
# SMB           -0.0053      0.106     -0.051      0.960      -0.212       0.202
# HML            0.0717      0.105      0.684      0.494      -0.134       0.277
# ==============================================================================
# Omnibus:                      359.200   Durbin-Watson:                   1.917
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8504.238
# Skew:                           1.681   Prob(JB):                         0.00
# Kurtosis:                      19.403   Cond. No.                         4.80
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Mkt-RF FF5+Mom
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         returns_Mkt-RF   R-squared:                       0.470
# Model:                            OLS   Adj. R-squared:                  0.465
# Method:                 Least Squares   F-statistic:                     106.4
# Date:                Tue, 07 May 2024   Prob (F-statistic):           7.33e-96
# Time:                        23:45:00   Log-Likelihood:                -2556.8
# No. Observations:                 728   AIC:                             5128.
# Df Residuals:                     721   BIC:                             5160.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0767      0.320      0.240      0.811      -0.551       0.705
# Mkt-RF         1.7569      0.076     22.969      0.000       1.607       1.907
# SMB            0.0749      0.110      0.680      0.496      -0.141       0.291
# HML            0.1638      0.146      1.120      0.263      -0.123       0.451
# RMW            0.2953      0.149      1.977      0.048       0.002       0.589
# CMA            0.0199      0.216      0.092      0.927      -0.404       0.443
# Mom            0.3466      0.076      4.577      0.000       0.198       0.495
# ==============================================================================
# Omnibus:                      373.244   Durbin-Watson:                   1.938
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8812.433
# Skew:                           1.778   Prob(JB):                         0.00
# Kurtosis:                      19.670   Cond. No.                         5.32
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# SMB CAPM
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            returns_SMB   R-squared:                       0.044
# Model:                            OLS   Adj. R-squared:                  0.042
# Method:                 Least Squares   F-statistic:                     33.25
# Date:                Tue, 07 May 2024   Prob (F-statistic):           1.20e-08
# Time:                        23:45:00   Log-Likelihood:                -2502.3
# No. Observations:                 728   AIC:                             5009.
# Df Residuals:                     726   BIC:                             5018.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1357      0.282      0.482      0.630      -0.417       0.689
# Mkt-RF         0.3585      0.062      5.766      0.000       0.236       0.481
# ==============================================================================
# Omnibus:                      129.678   Durbin-Watson:                   1.452
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2323.631
# Skew:                           0.092   Prob(JB):                         0.00
# Kurtosis:                      11.750   Cond. No.                         4.57
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# SMB FF3
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            returns_SMB   R-squared:                       0.483
# Model:                            OLS   Adj. R-squared:                  0.481
# Method:                 Least Squares   F-statistic:                     225.6
# Date:                Tue, 07 May 2024   Prob (F-statistic):          2.52e-103
# Time:                        23:45:00   Log-Likelihood:                -2278.3
# No. Observations:                 728   AIC:                             4565.
# Df Residuals:                     724   BIC:                             4583.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0400      0.209     -0.191      0.848      -0.450       0.370
# Mkt-RF         0.0309      0.049      0.633      0.527      -0.065       0.127
# SMB            1.7492      0.071     24.749      0.000       1.610       1.888
# HML            0.0291      0.070      0.415      0.679      -0.109       0.167
# ==============================================================================
# Omnibus:                      180.477   Durbin-Watson:                   1.520
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8278.708
# Skew:                          -0.094   Prob(JB):                         0.00
# Kurtosis:                      19.519   Cond. No.                         4.80
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# SMB FF5+Mom
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            returns_SMB   R-squared:                       0.494
# Model:                            OLS   Adj. R-squared:                  0.490
# Method:                 Least Squares   F-statistic:                     117.4
# Date:                Tue, 07 May 2024   Prob (F-statistic):          3.06e-103
# Time:                        23:45:00   Log-Likelihood:                -2270.4
# No. Observations:                 728   AIC:                             4555.
# Df Residuals:                     721   BIC:                             4587.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.2099      0.216     -0.972      0.331      -0.634       0.214
# Mkt-RF         0.0601      0.052      1.164      0.245      -0.041       0.161
# SMB            1.8456      0.074     24.833      0.000       1.700       1.992
# HML           -0.0189      0.099     -0.192      0.848      -0.213       0.175
# RMW            0.3908      0.101      3.878      0.000       0.193       0.589
# CMA            0.0828      0.146      0.569      0.570      -0.203       0.369
# Mom            0.0241      0.051      0.471      0.638      -0.076       0.124
# ==============================================================================
# Omnibus:                      176.831   Durbin-Watson:                   1.529
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7754.060
# Skew:                          -0.025   Prob(JB):                         0.00
# Kurtosis:                      18.988   Cond. No.                         5.32
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# HML CAPM
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            returns_HML   R-squared:                       0.021
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     15.66
# Date:                Tue, 07 May 2024   Prob (F-statistic):           8.35e-05
# Time:                        23:45:00   Log-Likelihood:                -2667.2
# No. Observations:                 728   AIC:                             5338.
# Df Residuals:                     726   BIC:                             5348.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.1294      0.353      3.198      0.001       0.436       1.823
# Mkt-RF        -0.3086      0.078     -3.957      0.000      -0.462      -0.155
# ==============================================================================
# Omnibus:                      151.628   Durbin-Watson:                   1.571
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3057.960
# Skew:                           0.324   Prob(JB):                         0.00
# Kurtosis:                      13.020   Cond. No.                         4.57
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# HML FF3
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            returns_HML   R-squared:                       0.387
# Model:                            OLS   Adj. R-squared:                  0.384
# Method:                 Least Squares   F-statistic:                     152.0
# Date:                Tue, 07 May 2024   Prob (F-statistic):           2.06e-76
# Time:                        23:45:00   Log-Likelihood:                -2497.1
# No. Observations:                 728   AIC:                             5002.
# Df Residuals:                     724   BIC:                             5021.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.4013      0.282      1.422      0.156      -0.153       0.955
# Mkt-RF        -0.0458      0.066     -0.695      0.487      -0.175       0.084
# SMB            0.0317      0.095      0.333      0.740      -0.156       0.219
# HML            1.9643      0.095     20.716      0.000       1.778       2.151
# ==============================================================================
# Omnibus:                      180.236   Durbin-Watson:                   1.668
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6351.069
# Skew:                           0.314   Prob(JB):                         0.00
# Kurtosis:                      17.456   Cond. No.                         4.80
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# HML FF5+Mom
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            returns_HML   R-squared:                       0.441
# Model:                            OLS   Adj. R-squared:                  0.437
# Method:                 Least Squares   F-statistic:                     94.87
# Date:                Tue, 07 May 2024   Prob (F-statistic):           9.93e-88
# Time:                        23:45:00   Log-Likelihood:                -2463.2
# No. Observations:                 728   AIC:                             4940.
# Df Residuals:                     721   BIC:                             4972.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.7636      0.281      2.715      0.007       0.211       1.316
# Mkt-RF        -0.1038      0.067     -1.544      0.123      -0.236       0.028
# SMB           -0.2369      0.097     -2.446      0.015      -0.427      -0.047
# HML            2.1859      0.129     17.001      0.000       1.933       2.438
# RMW           -1.1004      0.131     -8.378      0.000      -1.358      -0.842
# CMA           -0.3086      0.190     -1.627      0.104      -0.681       0.064
# Mom            0.0910      0.067      1.366      0.172      -0.040       0.222
# ==============================================================================
# Omnibus:                      188.549   Durbin-Watson:                   1.656
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7312.395
# Skew:                           0.349   Prob(JB):                         0.00
# Kurtosis:                      18.511   Cond. No.                         5.32
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# RMW CAPM
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            returns_RMW   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.5181
# Date:                Tue, 07 May 2024   Prob (F-statistic):              0.472
# Time:                        23:45:00   Log-Likelihood:                -2232.7
# No. Observations:                 728   AIC:                             4469.
# Df Residuals:                     726   BIC:                             4478.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.8731      0.194      4.491      0.000       0.491       1.255
# Mkt-RF        -0.0309      0.043     -0.720      0.472      -0.115       0.053
# ==============================================================================
# Omnibus:                      172.587   Durbin-Watson:                   1.765
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1150.522
# Skew:                           0.886   Prob(JB):                    1.47e-250
# Kurtosis:                       8.898   Cond. No.                         4.57
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# RMW FF3
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            returns_RMW   R-squared:                       0.083
# Model:                            OLS   Adj. R-squared:                  0.080
# Method:                 Least Squares   F-statistic:                     21.98
# Date:                Tue, 07 May 2024   Prob (F-statistic):           1.24e-13
# Time:                        23:45:00   Log-Likelihood:                -2201.2
# No. Observations:                 728   AIC:                             4410.
# Df Residuals:                     724   BIC:                             4429.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.0332      0.188      5.497      0.000       0.664       1.402
# Mkt-RF        -0.0085      0.044     -0.193      0.847      -0.095       0.078
# SMB           -0.3641      0.064     -5.728      0.000      -0.489      -0.239
# HML           -0.3407      0.063     -5.395      0.000      -0.465      -0.217
# ==============================================================================
# Omnibus:                      159.720   Durbin-Watson:                   1.772
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              974.704
# Skew:                           0.832   Prob(JB):                    2.22e-212
# Kurtosis:                       8.419   Cond. No.                         4.80
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# RMW FF5+Mom
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            returns_RMW   R-squared:                       0.394
# Model:                            OLS   Adj. R-squared:                  0.389
# Method:                 Least Squares   F-statistic:                     78.09
# Date:                Tue, 07 May 2024   Prob (F-statistic):           4.20e-75
# Time:                        23:45:00   Log-Likelihood:                -2050.7
# No. Observations:                 728   AIC:                             4115.
# Df Residuals:                     721   BIC:                             4147.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.6037      0.160      3.783      0.000       0.290       0.917
# Mkt-RF         0.0276      0.038      0.724      0.469      -0.047       0.103
# SMB           -0.0341      0.055     -0.621      0.535      -0.142       0.074
# HML           -0.3242      0.073     -4.444      0.000      -0.467      -0.181
# RMW            1.3735      0.075     18.429      0.000       1.227       1.520
# CMA           -0.1895      0.108     -1.761      0.079      -0.401       0.022
# Mom            0.0014      0.038      0.038      0.970      -0.073       0.076
# ==============================================================================
# Omnibus:                      239.087   Durbin-Watson:                   1.842
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2000.215
# Skew:                           1.232   Prob(JB):                         0.00
# Kurtosis:                      10.738   Cond. No.                         5.32
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# CMA CAPM
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            returns_CMA   R-squared:                       0.032
# Model:                            OLS   Adj. R-squared:                  0.031
# Method:                 Least Squares   F-statistic:                     24.31
# Date:                Tue, 07 May 2024   Prob (F-statistic):           1.02e-06
# Time:                        23:45:00   Log-Likelihood:                -2043.9
# No. Observations:                 728   AIC:                             4092.
# Df Residuals:                     726   BIC:                             4101.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.5327      0.150      3.551      0.000       0.238       0.827
# Mkt-RF        -0.1633      0.033     -4.931      0.000      -0.228      -0.098
# ==============================================================================
# Omnibus:                      104.231   Durbin-Watson:                   1.811
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              355.842
# Skew:                           0.657   Prob(JB):                     5.37e-78
# Kurtosis:                       6.163   Cond. No.                         4.57
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# CMA FF3
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            returns_CMA   R-squared:                       0.246
# Model:                            OLS   Adj. R-squared:                  0.243
# Method:                 Least Squares   F-statistic:                     78.66
# Date:                Tue, 07 May 2024   Prob (F-statistic):           4.74e-44
# Time:                        23:45:00   Log-Likelihood:                -1953.2
# No. Observations:                 728   AIC:                             3914.
# Df Residuals:                     724   BIC:                             3933.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2961      0.134      2.214      0.027       0.034       0.559
# Mkt-RF        -0.0746      0.031     -2.389      0.017      -0.136      -0.013
# SMB           -0.0045      0.045     -0.100      0.921      -0.093       0.084
# HML            0.6423      0.045     14.298      0.000       0.554       0.730
# ==============================================================================
# Omnibus:                       97.001   Durbin-Watson:                   1.903
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              428.407
# Skew:                           0.522   Prob(JB):                     9.39e-94
# Kurtosis:                       6.610   Cond. No.                         4.80
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# CMA FF5+Mom
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            returns_CMA   R-squared:                       0.514
# Model:                            OLS   Adj. R-squared:                  0.510
# Method:                 Least Squares   F-statistic:                     127.1
# Date:                Tue, 07 May 2024   Prob (F-statistic):          1.97e-109
# Time:                        23:45:00   Log-Likelihood:                -1793.3
# No. Observations:                 728   AIC:                             3601.
# Df Residuals:                     721   BIC:                             3633.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1988      0.112      1.774      0.076      -0.021       0.419
# Mkt-RF         0.0334      0.027      1.245      0.213      -0.019       0.086
# SMB           -0.0751      0.039     -1.946      0.052      -0.151       0.001
# HML            0.0707      0.051      1.380      0.168      -0.030       0.171
# RMW           -0.3615      0.052     -6.907      0.000      -0.464      -0.259
# CMA            1.2899      0.076     17.065      0.000       1.141       1.438
# Mom           -0.0537      0.027     -2.024      0.043      -0.106      -0.002
# ==============================================================================
# Omnibus:                      169.693   Durbin-Watson:                   1.874
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              934.946
# Skew:                           0.928   Prob(JB):                    9.53e-204
# Kurtosis:                       8.233   Cond. No.                         5.32
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Mom CAPM
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            returns_Mom   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.1415
# Date:                Tue, 07 May 2024   Prob (F-statistic):              0.707
# Time:                        23:45:00   Log-Likelihood:                -2947.5
# No. Observations:                 728   AIC:                             5899.
# Df Residuals:                     726   BIC:                             5908.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.0100      0.519      7.726      0.000       2.991       5.029
# Mkt-RF         0.0431      0.115      0.376      0.707      -0.182       0.268
# ==============================================================================
# Omnibus:                      244.528   Durbin-Watson:                   1.674
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1708.457
# Skew:                           1.326   Prob(JB):                         0.00
# Kurtosis:                      10.021   Cond. No.                         4.57
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Mom FF3
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            returns_Mom   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     3.131
# Date:                Tue, 07 May 2024   Prob (F-statistic):             0.0251
# Time:                        23:45:00   Log-Likelihood:                -2942.8
# No. Observations:                 728   AIC:                             5894.
# Df Residuals:                     724   BIC:                             5912.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.2027      0.521      8.072      0.000       3.181       5.225
# Mkt-RF         0.0266      0.122      0.218      0.827      -0.212       0.265
# SMB           -0.2445      0.176     -1.388      0.165      -0.590       0.101
# HML           -0.4597      0.175     -2.628      0.009      -0.803      -0.116
# ==============================================================================
# Omnibus:                      247.364   Durbin-Watson:                   1.672
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1736.420
# Skew:                           1.343   Prob(JB):                         0.00
# Kurtosis:                      10.073   Cond. No.                         4.80
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Mom FF5+Mom
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            returns_Mom   R-squared:                       0.309
# Model:                            OLS   Adj. R-squared:                  0.303
# Method:                 Least Squares   F-statistic:                     53.71
# Date:                Tue, 07 May 2024   Prob (F-statistic):           9.14e-55
# Time:                        23:45:00   Log-Likelihood:                -2813.1
# No. Observations:                 728   AIC:                             5640.
# Df Residuals:                     721   BIC:                             5672.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.7859      0.455      6.126      0.000       1.893       3.679
# Mkt-RF         0.3364      0.109      3.093      0.002       0.123       0.550
# SMB           -0.2164      0.157     -1.382      0.167      -0.524       0.091
# HML            0.4589      0.208      2.207      0.028       0.051       0.867
# RMW           -0.0361      0.212     -0.170      0.865      -0.453       0.381
# CMA           -0.6504      0.307     -2.120      0.034      -1.253      -0.048
# Mom            1.8861      0.108     17.517      0.000       1.675       2.097
# ==============================================================================
# Omnibus:                      372.770   Durbin-Watson:                   1.643
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4767.306
# Skew:                           1.986   Prob(JB):                         0.00
# Kurtosis:                      14.891   Cond. No.                         5.32
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
for factor in factors:
    m = indiv_port[f'returns_{factor}'].mean()
    print(f'{factor} mean monthly return: {m}')
# Out:
# Mkt-RF mean monthly return: 1.4568009274706042
# SMB mean monthly return: 0.34327447256959287
# HML mean monthly return: 0.9507457696501198
# RMW mean monthly return: 0.855247464813075
# CMA mean monthly return: 0.43818206049065234
# Mom mean monthly return: 4.034928537369595

# %% [markdown]
# ## Problem 2
#
# ### Part A - Calculate Monthly Volatility

# %%
comp_port = df_ff6.iloc[:, list(range(8)) + list(range(14, len(df_ff6.columns)))].copy()


lag_vars = ['lag_var_Mkt-RF', 'lag_var_SMB', 'lag_var_HML', 
                    'lag_var_RMW', 'lag_var_CMA', 'lag_var_Mom']

comp_port['tot_inv_var'] = comp_port[lag_vars].apply(lambda x: sum(1 / x), axis=1)

for factor in factors:
    comp_port[f'weight_{factor}'] = (1 / comp_port[f'lag_var_{factor}']) / comp_port['tot_inv_var']

rets = ['Mkt-RF', 'SMB', 'HML', 'RMW', 'CMA', 'Mom']
weights = ['weight_Mkt-RF', 'weight_SMB', 'weight_HML', 
        'weight_RMW', 'weight_CMA', 'weight_Mom']

comp_port['returns'] = (comp_port[weights].values * comp_port[rets].values).sum(axis=1)

comp_port
# Out:
#         date  Mkt-RF   SMB   HML   RMW   CMA    RF   Mom  lag_var_Mkt-RF  \
# 0    1963-08    5.07 -0.80  1.80  0.36 -0.35  0.25  1.01        0.223726
# 1    1963-09   -1.57 -0.52  0.13 -0.71  0.29  0.27  0.19        0.086949
# 2    1963-10    2.53 -1.39 -0.10  2.80 -2.01  0.29  3.12        0.154223
# 3    1963-11   -0.85 -0.88  1.75 -0.51  2.24  0.27 -0.74        0.171368
# 4    1963-12    1.83 -2.10 -0.02  0.03 -0.07  0.29  1.75        1.493974
# ..       ...     ...   ...   ...   ...   ...   ...   ...             ...
# 723  2023-11    8.84 -0.12  1.64 -3.91 -1.00  0.44  2.75        0.863721
# 724  2023-12    4.87  7.32  4.93 -3.07  1.32  0.43 -5.51        0.547768
# 725  2024-01    0.71 -5.74 -2.38  0.69 -0.96  0.47  5.19        0.406426
# 726  2024-02    5.06 -0.78 -3.49 -1.99 -2.14  0.42  4.96        0.537473
# 727  2024-03    2.83 -1.16  4.19  1.48  1.18  0.43 -0.42        0.767954
#
#      lag_var_SMB  ...  lag_var_CMA  lag_var_Mom  tot_inv_var  weight_Mkt-RF  \
# 0       0.020938  ...     0.031652     0.077050   168.326327       0.026554
# 1       0.033653  ...     0.023129     0.047702   205.924592       0.055850
# 2       0.052577  ...     0.028083     0.072686   138.191526       0.046921
# 3       0.077462  ...     0.085728     0.094405    65.797276       0.088687
# 4       0.207698  ...     0.081876     0.639916    42.530085       0.015738
# ..           ...  ...          ...          ...          ...            ...
# 723     0.412867  ...     0.145862     0.561597    17.300356       0.066922
# 724     1.151056  ...     0.090708     1.064724    19.922995       0.091632
# 725     0.973010  ...     0.102177     0.804803    21.955604       0.112066
# 726     0.613752  ...     0.087964     0.581611    23.200542       0.080195
# 727     1.372533  ...     0.318679     0.893207    10.957348       0.118839
#
#      weight_SMB  weight_HML  weight_RMW  weight_CMA  weight_Mom   returns
# 0      0.283737    0.156820    0.268094    0.187691    0.077103  0.298613
# 1      0.144301    0.122815    0.365272    0.209959    0.101801 -0.325869
# 2      0.137634    0.206431    0.251784    0.257674    0.099556  0.404444
# 3      0.196203    0.130505    0.246332    0.177283    0.160990  0.132693
# 4      0.113206    0.294017    0.253118    0.287177    0.036744 -0.163020
# ..          ...         ...         ...         ...         ...       ...
# 723    0.140002    0.158861    0.135009    0.396280    0.102925  0.194203
# 724    0.043606    0.122245    0.142022    0.553352    0.047142  1.402778
# 725    0.046810    0.095526    0.243243    0.445762    0.056593 -0.382848
# 726    0.070228    0.126650    0.158816    0.490003    0.074109 -1.088073
# 727    0.066492    0.198990    0.227125    0.286379    0.102174  1.724111
#
# [728 rows x 22 columns]

# %%
estimate_models(comp_port, f'returns', '')
# Out:
#  CAPM
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                returns   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     3.481
# Date:                Tue, 07 May 2024   Prob (F-statistic):             0.0625
# Time:                        23:45:01   Log-Likelihood:                -1060.9
# No. Observations:                 728   AIC:                             2126.
# Df Residuals:                     726   BIC:                             2135.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.3333      0.039      8.573      0.000       0.257       0.410
# Mkt-RF        -0.0160      0.009     -1.866      0.062      -0.033       0.001
# ==============================================================================
# Omnibus:                       45.823   Durbin-Watson:                   1.790
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              164.728
# Skew:                           0.138   Prob(JB):                     1.70e-36
# Kurtosis:                       5.314   Cond. No.                         4.57
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#  FF3
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                returns   R-squared:                       0.387
# Model:                            OLS   Adj. R-squared:                  0.385
# Method:                 Least Squares   F-statistic:                     152.6
# Date:                Tue, 07 May 2024   Prob (F-statistic):           1.20e-76
# Time:                        23:45:01   Log-Likelihood:                -884.21
# No. Observations:                 728   AIC:                             1776.
# Df Residuals:                     724   BIC:                             1795.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2510      0.031      8.150      0.000       0.191       0.311
# Mkt-RF        -0.0002      0.007     -0.030      0.976      -0.014       0.014
# SMB            0.0656      0.010      6.300      0.000       0.045       0.086
# HML            0.2063      0.010     19.947      0.000       0.186       0.227
# ==============================================================================
# Omnibus:                       50.674   Durbin-Watson:                   1.839
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              210.225
# Skew:                           0.096   Prob(JB):                     2.24e-46
# Kurtosis:                       5.626   Cond. No.                         4.80
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#  FF5+Mom
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                returns   R-squared:                       0.712
# Model:                            OLS   Adj. R-squared:                  0.710
# Method:                 Least Squares   F-statistic:                     297.8
# Date:                Tue, 07 May 2024   Prob (F-statistic):          2.31e-191
# Time:                        23:45:01   Log-Likelihood:                -608.87
# No. Observations:                 728   AIC:                             1232.
# Df Residuals:                     721   BIC:                             1264.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0759      0.022      3.447      0.001       0.033       0.119
# Mkt-RF         0.0463      0.005      8.798      0.000       0.036       0.057
# SMB            0.1186      0.008     15.635      0.000       0.104       0.133
# HML            0.1178      0.010     11.696      0.000       0.098       0.138
# RMW            0.1978      0.010     19.227      0.000       0.178       0.218
# CMA            0.2324      0.015     15.643      0.000       0.203       0.262
# Mom            0.0725      0.005     13.910      0.000       0.062       0.083
# ==============================================================================
# Omnibus:                       87.727   Durbin-Watson:                   1.730
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              489.665
# Skew:                          -0.362   Prob(JB):                    4.68e-107
# Kurtosis:                       6.952   Cond. No.                         5.32
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
